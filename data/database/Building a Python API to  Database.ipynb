# %% [markdown]
# # Building a Python API to Manage our MySQL Database

# %%
import pandas as pd
import sqlalchemy
import pymssql

# Database credentials, which we created before
SQL_USERNAME = "dtft_user"
SQL_PASSWORD = "DTFT"
SQL_DB_NAME = "dtft_db"

# Connection settings
SQL_DIALECT = "mysql"  # we are using MySQL
SQL_DRIVER = "pymysql"  # pymsql provides an interface between MySQL and Python

# The 
SQL_URL = "{}+{}://{}:{}@localhost:3306/{}".format(SQL_DIALECT,
                                                   SQL_DRIVER,
                                                   SQL_USERNAME,
                                                   SQL_PASSWORD,
                                                   SQL_DB_NAME)

SQL_URL
# Out:
# 'mysql+pymysql://dtft_user:DTFT@localhost:3306/dtft_db'

# %%
# Connect to the DB
engine = sqlalchemy.create_engine(SQL_URL, echo=True)

# %%
query_result = engine.execute("SELECT * FROM riskfreerate;")
# Out:
# 2020-12-14 11:20:27,434 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2020-12-14 11:20:27,442 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-14 11:20:27,450 INFO sqlalchemy.engine.base.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2020-12-14 11:20:27,450 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-14 11:20:27,454 INFO sqlalchemy.engine.base.Engine SELECT DATABASE()
# 2020-12-14 11:20:27,454 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-14 11:20:27,462 INFO sqlalchemy.engine.base.Engine show collation where `Charset` = 'utf8mb4' and `Collation` = 'utf8mb4_bin'
# 2020-12-14 11:20:27,464 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-14 11:20:27,471 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS CHAR(60)) AS anon_1
# 2020-12-14 11:20:27,474 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-14 11:20:27,474 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS CHAR(60)) AS anon_1
# ...

# %%
df1 = pd.read_sql(sql="SELECT * FROM riskfreerate;", con=engine)
df1
# Out:
# 2020-12-14 11:20:29,825 INFO sqlalchemy.engine.base.Engine DESCRIBE `SELECT * FROM riskfreerate;`
# 2020-12-14 11:20:29,826 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-14 11:20:29,829 INFO sqlalchemy.engine.base.Engine ROLLBACK
# 2020-12-14 11:20:29,829 INFO sqlalchemy.engine.base.Engine SELECT * FROM riskfreerate;
# 2020-12-14 11:20:29,837 INFO sqlalchemy.engine.base.Engine {}
#            Dates   Yield
# 0     03.01.2005  4.2104
# 1     04.01.2005  4.2886
# 2     05.01.2005  4.2808
# 3     06.01.2005  4.2612
# 4     07.01.2005   4.269
# ...          ...     ...
# 4134  09.11.2020  0.9235
# 4135  10.11.2020  0.9595
# 4136  11.11.2020  0.9753
# 4137  12.11.2020  0.8815
# 4138  13.11.2020  0.8963
#
# [4139 rows x 2 columns]

# %%
df2 = pd.read_sql(sql="SELECT * FROM sp500;", con=engine)
df2
# Out:
# 2020-12-14 11:20:31,552 INFO sqlalchemy.engine.base.Engine DESCRIBE `SELECT * FROM sp500;`
# 2020-12-14 11:20:31,552 INFO sqlalchemy.engine.base.Engine {}
# 2020-12-14 11:20:31,552 INFO sqlalchemy.engine.base.Engine ROLLBACK
# 2020-12-14 11:20:31,561 INFO sqlalchemy.engine.base.Engine SELECT * FROM sp500;
# 2020-12-14 11:20:31,561 INFO sqlalchemy.engine.base.Engine {}
#         Dates      AUN    AALUW   AAPUN  AAPLUW   ABBVUN    ABCUN  ABMDUW  \
# 0     03/01/2  16.0896  #N/A N/  29.033   1.131  #N/A N/  14.1063   15.01
# 1     04/01/2  15.6652  #N/A N/   28.84   1.142  #N/A N/  13.9947   14.98
# 2     05/01/2  15.6584  #N/A N/  28.893   1.152  #N/A N/   13.968   14.69
# 3     06/01/2  15.3148  #N/A N/  28.867   1.153  #N/A N/  14.0869   14.52
# 4     07/01/2  15.3013  #N/A N/    28.7   1.237  #N/A N/  14.0456   14.29
# ...       ...      ...      ...     ...     ...      ...      ...     ...
# 4121  20/10/2   105.61     12.8  153.02  117.51    84.25    97.99  277.53
# ...
